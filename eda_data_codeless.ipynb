# %% [markdown]
# # Análise de Dados e *Machine Learning* - NHL
#
# <p align="center">
#     <img width=550 src="https://github.com/DanOliveira-DS/NHL/blob/master/images/web_hockey_basen_art.jpg?raw=true">
# </p>
#
# Muito inspirado por Michael Lewis e seu livro "*Moneyball: The Art of Winning an Unfair Game*" (leitura obrigatória para amantes da area que foi adaptado para o cinema com o título "O Homem que Mudou o Jogo", do diretor Bennett Miller) mostrou como a análise de dados aliado a um plano de jogo podem ser uma combinação fantástica. Nos últimos anos os avanços na tecnologia (dispositivos e sensores wearable como pulseiras eletrônicas, coletes, dispositivos GPS e outras tecnologias inteligentes) nos permitiram coletar cada vez mais dados. Entretanto, um monte de dados acumulados não são úteis se você não consegue interpretá-los. Portanto, tão importante quanto coletar dados estatísticos é saber decifrá-los. Com isso, a ciência de dados aplicada aos esportes já é uma realidade porque agora somos capazes de gerar valor através desses dados auxiliando assim nas tomadas de decisão.
#
# A análise desses novos dados possibilitou não apenas verificar estatísticas clássicas (vitorias, derrotas, gols feitos, gols sofridos..), mas tambem as estatísticas avançadas que procuram entender as diferentes maneiras com que uma jogada ou jogador pode influenciar uma partida. Com isso os times passaram a ser mais competitivos, sendo capazes de se prepararem  para um adversário ou até mesmo um jogador especifico que querem anular em uma partida. Tudo isso graças ao cruzamento de dados do histórico de desempenho dos atletas.
#
# Outro uso da coleta desses dados está em beneficiar as grandes organizações com dados sociais, onde pode-se encontrar padrões e formar grupos dentro da base de fãs e executar campanhas em grupos-alvo. Conhecendo os fatores que mais atraem os fãs, a gestão das equipes pode se concentrar em melhorar esse aspecto, o que leva a ganhar novos fãs e reter os mais antigos. Os fãs podem ser alimentados com uma quantidade enorme de previsões e possibilidades em tempo real com as estatísticas do seu time ou jogador favorito onde podem comparar a sua performance com os outros jogadores no time rival ou do mesmo time.
#
#
# A ciencia de dados tenta da sua maneira explorar as mesmas perguntas que os fãs e os treinadores se perguntam: quem eu acho que vai ganhar, e por quê? Quem são os melhores jogadores do mundo neste momento? Que estratégias são melhores, e porquê?.
#
# <p align="center">
#     <img width=650 src="https://github.com/DanOliveira-DS/NHL/blob/master/images/player.png?raw=true">
# </p>
#
# Mas é bom não confiar cegamente nas estatísticas. Por mais que o esporte americano seja excelente para criar uma base sólida de dados, o fator humano nunca pode ser deixado de lado. As estatísticas podem dizer algo, mas o contexto precisa ser levado em conta. Fatores que ainda não são representados nos dados, como a condição psicológica e o humor dos jogadores, também são chaves importantes na hora de analisar o jogo.

# %% [markdown]
# # Importando Bibliotecas

# %%
# suprimir avisos
import warnings
warnings.filterwarnings("ignore")
# bibliotecas para analise dos dados
import pandas as pd # procesamento dos dados
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

from nhl_functions import show_goals, show_goals_result, team_win_loss

from IPython.display import Image

# %% [markdown]
# # Aquisição dos Dados
# Os dados que usaremos nesse projeto foram coletados utilizando a **NHL stats API** e desponibilizados por Martin Ellis na plataforma Kaggle no formato *.csv*. Não são apenas os resultados e as estatísticas dos jogos da NHL, mas também detalhes de jogadas individuais, como chutes, gols e defesas, incluindo data, hora e coordenadas x e y. Ao total são 9 conjuntos de dados que se relacionam como apresentado na tabela abaixo:
#
# <p align="center">
#     <img width=900 src="https://github.com/DanOliveira-DS/NHL/blob/master/images/table_relationships.JPG?raw=true">
# </p>

# %% [markdown]
# # Descrição dos conjuntos de dados:
#
# * **game**: Reúne os registros de cada jogo no conjunto de dados;
#
# * **game_golie_stats**: As estatísticas dos goleiros que participaram dos jogos;
#
# * **game_plays**: As jogadas individuais (eventos) de cada jogo;
#
# * **game_plays_player**: Os jogadores envolvidos em uma jogada;
#
# * **game_skater_stats**: As estatísticas básicas dos jogadores. 36 entradas por jogo, uma para cada jogador do time;
#
# * **game_teams_stats**: As estatísticas básicas das equipes. Cada jogo terá duas entradas nesta tabela, uma para cada equipe;
#
# * **player_info**: Informações sobre os jogadores;
#
# * **team_info**: informação sobre as equipes.
#
# Caso esteja interessado em ver como os dados são coletados, indico o vídeo do [Kevin Sidwar](https://www.youtube.com/watch?v=avp7fvuMT1E&t=214s). Ele é também um dos responsaveis por dar inicio a documentação da NHL stats api

# %% [markdown]
# # Importando os conjuntos de dados

# %%
# nhl_eda
nhl_eda = pd.read_csv('datasets/nhl_eda_cleaned.csv', index_col='game_id')

# %% [markdown]
# Para facilitar nosso entendimento, vamos trabalhar cada categoria de dados que temos separadamente. Elas são:
# * Estatísticas dos times da NHL.
# * Estatísticas dos jogadores de todas as equipes.
# * Estatísticas dos eventos os jogos.

# %% [markdown]
# # Analise Exploratoria dos Dados
# Antes de resolver um problema, é preciso conhecer os dados. A Análise Exploratória de Dados reúne um conjunto de ferramentas úteis para resumir e visualizar as características de uma base de dados. Deve ser parte fundamental de qualquer projeto de ciência de dados. Essas técnicas possibilitam criar uma primeira intuição sobre os dados, o que permite conhecer as suas informações, padrões e lançar hipóteses. Assim, gerando insights que auxiliam na criação de modelos de Machine Learning.
#
# **Levantamento de hipóteses**
# * Todas as temporadas tiveram os mesmos números de jogos?
# * Qual time com mais jogos na **NHL**?
# * Qual time possui o melhor aproveitamento na fase regular e o na pós-temporada?
# * O time com o melhor desempenho na fase regular foi o campeão na pós-temporada (*playoffs*)?
# * Times mandantes jogam melhor em casa?
# * Qual foi o maior número de gols feito por um time em uma partida?
# * Qual a media de gols por time?
# * Como está desempenho do ataque e defesa dos times nas temporadas?
# * Qual time acumula mais Hits e PIMs?
# * O jogo ficou mais físico (mais hits) durante os anos (season) ouve aumento nas penalidades?
# * Os times com maior número de hits e pim como foi o desempenho através das temporadas

# %% [markdown]
# ## Conhecendo o conjunto de dados
# A primeira coisa que faremos após importar o dataset será examinar as dimensões do DataFrame e as primeiras entradas. Isso possibilitará criar uma consciência situacional inicial a respeito do formato de entrada e da estrutura geral dos dados.

# %% [markdown]
# ### Qual o tamanho do conjunto de dados? (Quantas observações e features)

# %%
# Dimensao do conjunto de dados nhl_eda
print("Dimensão do conjunto de dados:")
print(f"Observações: {nhl_eda.shape[0]}")
print(f"Variáveis:   {nhl_eda.shape[1]}")
# Out:
# Dimensão do conjunto de dados:
# Observações: 22868
# Variáveis:   18

# %%
# primeiras entradas
nhl_eda.head()
# Out:
#               season type   date_time team_name  goals_for  goals_against  \
# game_id
# 2011030221  20112012    P  2012-04-29    Devils          3              4
# 2011030221  20112012    P  2012-04-29    Flyers          4              3
# 2011030222  20112012    P  2012-05-01    Devils          4              1
# 2011030222  20112012    P  2012-05-01    Flyers          1              4
# 2011030223  20112012    P  2012-05-03    Flyers          3              4
#
#              HoA settled_in        head_coach  shots  hits  pim  \
# game_id
# 2011030221  away         OT      Peter DeBoer     26    31   12
# 2011030221  home         OT  Peter Laviolette     36    27    6
# 2011030222  away        REG      Peter DeBoer     35    32   12
# 2011030222  home        REG  Peter Laviolette     20    24   32
# 2011030223  away         OT  Peter Laviolette     28    28    4
#
#             powerPlayOpportunities  powerPlayGoals  faceOffWinPercentage  \
# game_id
# 2011030221                       3               1                  44.9
# 2011030221                       6               1                  55.1
# 2011030222                       4               0                  50.9
# 2011030222                       5               0                  49.1
# 2011030223                       5               1                  50.8
#
#             giveaways  takeaways outcome
# game_id
# 2011030221          6          7       L
# 2011030221         13          4       W
# 2011030222          8          7       W
# 2011030222          9          6       L
# 2011030223          2          1       L

# %% [markdown]
# Descrição das variáveis:
# * `game_id` - Número identificador da partida.
# * `season` - Temporada em que ocorreu o jogo
# * `type` - Indica se os jogos aconteceram na temporada regular (R) ou playoffs (P)
# * `date_time` - Data que ocorreu a partida
# * `team_name` - Nome do time
# * `goals_for` - Número de gols a favor
# * `goals_against` - Número de gols contra
# * `HoA` - Indica se o time jogou como mandante (*home*) ou visitante (*away*)
# * `settled_in` - Indica como o jogo foi resolvido: tempo regular (REG), overtime (OT) ou shootout (SO)
# * `head_coach` - Nome do técnico
# * `shots` - Número de shots dado pelo time na partida
# * `hits` - Número de hits dado pelo time na partida
# * `pim` - Minutos de penalização atribuídos ao jogador.
# * `powerPlayOpportunities` - Contabiliza o número de oportunidades no *power plays*
# * `powerPlayGoals` - Número de gols no *power plays*
# * `faceOffWinPercentage` - Porcentagem de vitória no faceoff
# * `giveaways` - Contabiliza o erro que faz com que um jogador com posse do disco o perca para um jogador do time adversário.
# * `takeways` - Contabiliza a ação forçada tomada por um jogador defensivo para recuperar a posse do disco para sua equipe
# * `outcome` - Resultado da partida: L (derrotado) e W (vitorioso)

# %% [markdown]
# ### Estatística descritiva  dos dados
# Como o nome sugere, ajudam a descrever e compreender os conjuntos de dados, apresentando-os de uma maneira mais significativa, o que permite uma interpretação mais simples dos dados. Aqui vamos ter as medidas de tendências centrais e de variabilidade.
# As medidas de tendências centrais representa o ponto central ou valor típico de um conjunto de dados (**media, mediana e a moda**). Já as medidas de variabilidade representa a quantidade de dispersão num conjunto de dados, ou seja, definem a distância a que os pontos de dados tendem a cair do centro (**variância, desvio padrão, intervalo interquartil..**)
#
# No pandas podemos usar a função *describe()* onde imediatamente obtemos um resumo contendo algumas das principais informações estatísticas relevantes:
#
# * count – quantidade de entradas válidas
# * mean – média dos valores
# * std – desvio padrão
# * min – menor valor da coluna
# * 25% - (Q1) primeiro quartil 25
# * 50% - mediana
# * 75% - (Q3) terceiro quartil 75
# * max – maior valor da coluna
#
# Ainda é possível identificar colunas com possíveis *outliers* (por exemplo, olhando o valor da mediana e comparando com valores máximos e mínimos)

# %%
# resumo estatistico
nhl_eda.describe()
# Out:
#              season     goals_for  goals_against         shots          hits  \
# count  2.286800e+04  22868.000000   22868.000000  22868.000000  22868.000000
# mean   2.014315e+07      2.743047       2.794254     30.396405     23.607574
# std    2.609836e+04      1.640201       1.641038      6.832590      8.595527
# min    2.010201e+07      0.000000       0.000000     10.000000      2.000000
# 25%    2.012201e+07      2.000000       2.000000     26.000000     17.000000
# 50%    2.014202e+07      3.000000       3.000000     30.000000     23.000000
# 75%    2.016202e+07      4.000000       4.000000     35.000000     29.000000
# max    2.018202e+07     10.000000      10.000000     64.000000     80.000000
#
#                 pim  powerPlayOpportunities  powerPlayGoals  \
# count  22868.000000            22868.000000    22868.000000
# mean      10.175791                3.179334        0.592356
# std        8.038863                1.562107        0.759193
# min        0.000000                0.000000        0.000000
# 25%        6.000000                2.000000        0.000000
# 50%        8.000000                3.000000        0.000000
# 75%       12.000000                4.000000        1.000000
# max      183.000000               12.000000        6.000000
#
#        faceOffWinPercentage     giveaways     takeaways
# count          22868.000000  22868.000000  22868.000000
# mean              50.000000      8.648155      6.919801
# std                7.203451      4.861654      3.840531
# min               20.800000      0.000000      0.000000
# 25%               45.200000      5.000000      4.000000
# 50%               50.000000      8.000000      6.000000
# 75%               54.800000     12.000000      9.000000
# max               79.200000     36.000000     31.000000

# %% [markdown]
# Podemos ver que grande parte das nossas variáveis apresentaram valores discrepantes (*outliers*). Entender a presença desses outliers é importante porque os valores discrepantes distorcem nossa distribuição o que pode influenciar negativamente na performance dos algoritmos de machine learning já que eles assumem uma distribuição normal (gaussiana) nas variáveis de entrada.
#
# Uma das alternativas e filtrar esses valores discrepantes, mas isso significa a perda de informação. Portanto, antes de qualquer ação vamos investigá-los e ver o quanto significativos são.
#
# Como o cérebro humano tem dificuldade de processar grandes volumes de dados, uma das melhores abordagens é plotar a distribuição das variáveis. E o histograma e um gráfico que casa muito com o resumo estatístico que apresentamos. Vamos ao gráfico

# %% [markdown]
# ### Histogramas
#
# Sao maneira rápida de ter uma ideia da distribuição de cada atributo é observar os histogramas. Os histogramas agrupam dados em posições e fornecem uma contagem do número de observações em cada posição. A partir da forma das caixas, você pode ter uma ideia rápida de se um atributo é gaussiano, inclinado(skewed) ou mesmo tem uma distribuição exponencial. Também pode ajudar a ver possíveis discrepâncias.

# %%
# histograma
nhl_eda.hist(figsize=(14, 4), layout=(2,6))
plt.tight_layout()

# %% [markdown]
# * O comportamento exponencial visto nas variáveis `pim`, `powerPlayGoals` mostra a influência dos valores discrepantes distorcendo a distribuição. Na variavel `pim` por exemplo temos uma media de 10 min e um valor maximo de 183 minutos.
# * As variavel `season` apresentou um comportamento uniforme com uma queda bastante brusca. Vamos investigar para tentar responder tao comportamento.
# * As outras variáveis apesar de apresentarem valores discrepantes como foi visto no resumo estatístico aparentemente não sofreu tanta influência do mesmo uma vez que a distribuição lembra bastante a normal (gaussiana).

# %% [markdown]
# ## Quantos jogos no total tivemos por temporada ?
# No gráfico anterior vimos que nossa variável `season` vinha apresentando um comportamento uniforme ate ter um queda bem brusca na sua distribuição. Utilizando o gráfico de barras vamos verificar quantos jogos ao total tivemos por temporada incluindo as duas fases  regular e pós-temporada, com o intuito de tentar entender o que aconteceu.

# %%
Image(filename='images/totaljogostemp.png', width=750)

# %% [markdown]
# Nosso gráfico mostra que a temporada de 2012-2013 foi menor que as demais o que explica a distorção que vimos na distribuição da variável `season` quando apresentamos o histograma. O motivo foi o chamado *lockout* que é quando proprietários e jogadores não concordam com os termos de renovação do Contrato de Negociação Coletiva (CBA). Na temporada em questão a fase regular teve apenas 48 jogos. Para ler mais acesse [NHeLas](http://nhelas.com/o-que-e-um-lockout-e-como-funciona/).

# %% [markdown]
# ### Qual a porcentagem de jogos reprentam a temporada regular e os playoffs?
#
# A liga nacional de hoquei (NHL) e dividida em duas fase a temporada Regular e os Playoffs. Queremos saber qual a sua representividade no conjunto de dados

# %%
Image(filename='images/relacaoregoffs.png')

# %% [markdown]
# Tivemos um resultado bastante desbalanceado. Isso mostra que apenas uma pequena parcela dos nossos dados representam a pós-temporada. Essa grande diferença se deve ao formato da própria liga, onde na temporada regular temos 82 jogos fixos, isso se nada acontecer como foi o *lockout* na temporada de 2012-2013, e na pós-temporada de 16 a 28 jogos.

# %% [markdown]
# ## Qual time possui o maior número de jogos ?
# Agora que sabemos a quantidade total de jogos por temporada e como os jogos estão dispostos em relação a fase regular e os playoffs. Hora de verificar a quantidade de jogos dos time na **NHL** no período que abragem os nossos dados (2010-2011 ~ 2018-2019) neste dois quesitos. Vale lembrar que para jogar os playoffs o time precisa de uma boa campanha na temporada regular. Nossa tabela vai representar o total de jogos tanto na fase regular como nos *playoffs* e nosso gráfico vai apresentar a soma total.

# %%
teams_games = pd.read_csv("nhl_datasets/games_teams_df.csv", index_col=0)
print("Tabela")
print(teams_games.to_string())
# Out:
# Tabela
#                 regular  playoffs  total_jogos
# Penguins            704       111          815
# Bruins              704       108          812
# Sharks              704       101          805
# Capitals            704       100          804
# Rangers             704        98          802
# Blackhawks          704        89          793
# Lightning           704        86          790
# Blues               704        84          788
# Predators           704        83          787
# Kings               704        79          783
# Ducks               704        70          774
# Red Wings           704        47          751
# Canadiens           704        47          751
# Wild                704        44          748
# Senators            704        42          746
# Flyers              704        41          745
# Canucks             704        40          744
# Islanders           704        32          736
# Stars               704        32          736
# Devils              704        29          733
# Blue Jackets        704        27          731
# Maple Leafs         704        27          731
# Avalanche           704        25          729
# Coyotes             704        20          724
# Flames              704        20          724
# Hurricanes          704        15          719
# Oilers              704        13          717
# Panthers            704        13          717
# Sabres              704         7          711
# Jets                622        27          649
# Golden Knights      164        27          191
# Thrashers            82         0           82

# %%
Image(filename="images/jogostime.png")

# %% [markdown]
# ### Qual foi o desempenho das equipes?

# %% [markdown]
# Agora que ja sabemos quantos jogos cada equipe teve e hora que analisar os desempenhos.
#
# Vale ressaltar que comparar o desempenho das equipes nos playoffs entre elas fica dificil. Isso porque, apesar de ter quase 10 anos de dados sendo analisados, existe uma diferença enorme entre quantidade de jogos referente a temporada regular e os playoffs. Isso acaba sendo uma influencia enorme porque temos times com mais de 100 jogos nos *playoffs* enquanto outros apenas com 7, logo não temos uma leitura totalmente verdadeira o que acabada sendo uma comparação desleal.

# %%
# importando conjunto de dados
team_wins = pd.read_csv("nhl_datasets/teams_win_rate_df.csv", index_col=0)
team_wins[["win_rate_regular", "win_rate_playoffs"]].style.format({'win_rate_regular': "{:.2%}", 'win_rate_playoffs': '{:.2%}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >win_rate_regular</th>        <th class="col_heading level0 col1" >win_rate_playoffs</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row0" class="row_heading level0 row0" >Penguins</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row0_col0" class="data row0 col0" >59.50%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row0_col1" class="data row0 col1" >53.20%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row1" class="row_heading level0 row1" >Capitals</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row1_col0" class="data row1 col0" >58.00%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row1_col1" class="data row1 col1" >53.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row2" class="row_heading level0 row2" >Golden Knights</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row2_col0" class="data row2 col0" >57.30%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row2_col1" class="data row2 col1" >59.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row3" class="row_heading level0 row3" >Bruins</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row3_col0" class="data row3 col0" >57.20%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row3_col1" class="data row3 col1" >57.40%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row4" class="row_heading level0 row4" >Blues</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row4_col0" class="data row4 col0" >57.20%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row4_col1" class="data row4 col1" >50.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row5" class="row_heading level0 row5" >Lightning</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row5_col0" class="data row5 col0" >57.10%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row5_col1" class="data row5 col1" >54.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row6" class="row_heading level0 row6" >Sharks</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row6_col0" class="data row6 col0" >55.40%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row6_col1" class="data row6 col1" >51.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row7" class="row_heading level0 row7" >Ducks</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row7_col0" class="data row7 col0" >55.00%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row7_col1" class="data row7 col1" >51.40%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row8" class="row_heading level0 row8" >Blackhawks</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row8_col0" class="data row8 col0" >54.70%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row8_col1" class="data row8 col1" >57.30%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row9" class="row_heading level0 row9" >Rangers</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row9_col0" class="data row9 col0" >53.80%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row9_col1" class="data row9 col1" >48.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row10" class="row_heading level0 row10" >Predators</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row10_col0" class="data row10 col0" >53.30%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row10_col1" class="data row10 col1" >51.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row11" class="row_heading level0 row11" >Kings</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row11_col0" class="data row11 col0" >51.40%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row11_col1" class="data row11 col1" >55.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row12" class="row_heading level0 row12" >Wild</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row12_col0" class="data row12 col0" >50.90%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row12_col1" class="data row12 col1" >34.10%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row13" class="row_heading level0 row13" >Canadiens</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row13_col0" class="data row13 col0" >50.90%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row13_col1" class="data row13 col1" >46.80%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row14" class="row_heading level0 row14" >Jets</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row14_col0" class="data row14 col0" >50.60%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row14_col1" class="data row14 col1" >40.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row15" class="row_heading level0 row15" >Stars</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row15_col0" class="data row15 col0" >50.60%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row15_col1" class="data row15 col1" >50.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row16" class="row_heading level0 row16" >Flyers</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row16_col0" class="data row16 col0" >49.90%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row16_col1" class="data row16 col1" >39.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row17" class="row_heading level0 row17" >Blue Jackets</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row17_col0" class="data row17 col0" >49.40%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row17_col1" class="data row17 col1" >40.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1level0_row18" class="row_heading level0 row18" >Flames</th>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row18_col0" class="data row18 col0" >48.90%</td>
#                         <td id="T_994ccf1c_d80f_11ea_8d19_4931c6d0a2e1row18_col1" class="data row18 col1" >30.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_994ccf1c_d80f_11ea_8d19_49

# %% [markdown]
# * O time do ***Pittsburgh Penguins*** e aquele apresentou o melhor desempenho na temporada regular caindo um pouco nos playoffs, mas mantendo a taxa de vitórias acima dos 50%.
# * O time do ***Vegas Golden Knights*** pode ser considerado um ponto fora da curva. Tem um ótimo aproveitamento na temporada regular 57% e melhor ainda nos playoffs subindo para 59%. Entretanto, o fato de ter poucos jogos em comparação aos outros times não é algo que possa ser levado em comparação, mas sem dúvidas não tira o mérito do time.
# * Observando os desempenhos em relação aos *playoffs* é interessante ver como alguns times melhoram e muito seu aproveitamento em relação a temporada regular. Como é o caso dos ***Senators*, *Devils*, *Hurricanes* e *Oilers***. Entretanto, são times com um baixo aproveitamento na fase regular o que limita as chances de ida aos *playoffs* sendo assim acumulam poucos jogos na pós-temporada para uma análise mais profunda, mas que podem surpreender quando estão presentes nessa fase.

# %% [markdown]
# ### Jogar em casa influencia na vitória?
# Isso chega a ser mais uma questão psicológica. Uma vez que a vantagem de jogar em casa é de que você está familiarizado com o meio ambiente. Claro que a grande vantagem para um time da casa é a multidão. Pessoas torcendo por você com entusiasmo quando você marca ou faz uma grande jogada é bastante inspirador, então há quase uma sensação de “preciso impressionar essas pessoas” para os jogadores.
#
# Algumas vantagens que o time jogando em casa no hóquei tem:
# * As equipes da casa realizam a última alteração antes da disputa do *faceoff* (por exemplo, se o técnico vê os visitantes colocarem sua melhor linha ofensiva, ele pode neutralizar colocando sua melhor linha defensiva).
# * Nos *faceoffs*, o jogador da casa pode colocar o seu taco (*stick*) no gelo depois do adversário. O visitante deve colocar o seu taco no chão primeiro ou será substituído por outro jogador que fara a disputa do *faceoff*. Teoricamente, isto dá à equipa da casa uma ligeira vantagem.
#
# Nossos dados mostraram que:

# %%
Image(filename="images/winshome.png")

# %% [markdown]
# Isso demonstra que essas ligeiras vantagens de fato favorecem os times mandantes.

# %% [markdown]
# ## O time que teve o melhor desempenho na temporada regular foi o campeão?
# Aqui procuramos ver se o time que teve a melhor campanha na fase regular conseguiu transformar esse favoritismo em realidade ou se a pos temporada (*playoffs*) é uma fase onde todos possuem chances.

# %%
best_teams = pd.read_csv("nhl_datasets/champions_df.csv")
best_teams
# Out:
#      season   team_name  regular_wins  playoff_wins  sc_campeao
# 0  20102011     Canucks            54            15      Bruins
# 1  20112012     Canucks            51             1       Kings
# 2  20122013  Blackhawks            36            16  Blackhawks
# 3  20132014      Bruins            54             7       Kings
# 4  20142015     Rangers            53            11  Blackhawks
# 5  20152016    Capitals            56             6    Penguins
# 6  20162017    Capitals            55             7    Penguins
# 7  20172018   Lightning            54            11    Capitals
# 8  20182019   Lightning            62             0       Blues

# %% [markdown]
# * O ***Chicago Blackhawks*** foi o único time a conseguir vencer a *Stanley Cup* no mesmo ano em que teve a melhor campanha na fase regular.
# * Tivemos algumas decepções como o time do ***Vancuver Canucks***  na temporada de 2010-2011 que liderou a liga em vitórias na fase regular chegando as finais da *Stanley Cup*, mas perdeu para o time de Boston os ***Bruins***. No ano seguinte na temporada de 2011-2012 repetiu o feito na fase regular se mantendo no topo, mas caiu logo na primeira rodada dos *playoffs* vencendo apenas um único jogo.
# * Outro que decepcionou foi o time do ***Tampa Bay Lighting*** que assim como os *Canucks* teve duas ótimas temporadas (2017-2018 e 2018-2019) sendo que na última alcançou incríveis 62 vitórias, empatando o recorde da NHL no número de vitórias em uma temporada. No entanto, foram varridos em quatro jogos pelo ***Columbus Blue Jackets***, tornando-se o primeiro vencedor do Troféu dos Presidentes, dado ao melhor time da temporada regular, a não ganharem nenhum jogo na pós-temporada.
# * Com isso vemos que na maioria das vezes ter um resultado convincente na fase regular é animador, mas não garante sucesso nos *playoffs* reforçando a ideia de que os *playoffs* é uma etapa onde tudo pode acontecer.

# %% [markdown]
# Agora vamos ver como esta a relação de vitórias e derrotas dos times durante as temporadas.

# %%
#team_name = input("Select team: ")
for team in list(nhl_eda["team_name"].sort_values().unique()):
    team_win_loss(df=nhl_eda, team_name=team)

# %% [markdown]
# É difícil um time se manter no topo por muito tempo. E existem diversas razões para isso, mas a mais comum e a idade dos jogadores um time mais velho apesar de experiente tende a cair de produção o que pode levar algumas franquias a entrarem no processo de reconstrução (*rebuild*) que significa trocar voluntariamente seu núcleo antigo por um novo núcleo ou jogadores para complementar um núcleo jovem.

# %% [markdown]
# ## Gols
# Hora de analisar o quesito que dá aos times a vitória. No hóquei no gelo, um gol é marcado quando o disco cruza completamente a linha de gol entre os dois postes e abaixo da barra de gol.
#
# <p align="center">
#     <img width=850 src="https://nhl.bamcontent.com/images/photos/290404508/960x540/cut.jpg">
# </p>
#
# foto retirada da [NHL](https://www.nhl.com/news/nhl-network-top-50-overtime-goals-of-2016-17/c-290392098)

# %% [markdown]
# ### Como esta a distribuição dos gols feitos e sofridos?
# Como apresentamos antes os times que jogam em casa vencem os jogos 54% da vezes. Agora queremos saber como esta a distribuicao dos gols feitos e sofrido. Para essa analise vamos usar o grafico de caixa o *box plot*
#
# #### *Box plot*
#
# Um gráfico de caixa é um método para representar graficamente grupos de dados numéricos através de seus quartis. São uma maneira padronizada de exibir a distribuição de dados com base em um resumo de cinco números (“mínimo”, primeiro quartil (Q1), mediana, terceiro quartil (Q3) e “máximo”). Pontos extremos (outliers) são aqueles que passaram do fim dos bigodes e identificá-los é importante porque eles podem distorcer uma distribuição de probabilidade.
#
#
# <p style="float:left">
#     <img width=850 src="https://raw.githubusercontent.com/DanOliveira-DS/NHL/master/images/distribgols.png">
# </p>

# %% [markdown]
# O gráfico representa a distribuição dos gols feitos e sofridos dos times mandantes. Não é preciso apresentar um gráfico dos times visitantes porque acabaria sendo redundante uma vez que apenas a ordem mudaria. Os gols sofridos passariam a ser os gols feitos e os gols feitos passariam a ser os gols sofridos. No final a informação passada seria a mesma.
#
# Conclusões:
# * Nosso box plot mostra que os times mandantes tendem a marcar de 2 a 4 gols em 50% das vezes com uma média próxima dos 3 gols. Já os times visitantes apresentam uma distribuição um pouco mais elástica marcando de 1 a 4 gols em 50% das vezes e com uma média superior a 2,5 gols.
# * O maior valor discrepante (*outlier*) registrado em nosso conjunto de dados foi de 10 gols marcados por um mesmo time em uma partida.
#
# * De uma forma geral nosso gráfico apresentou bastante equilíbrio entre as equipes e que o fator casa não influenciou tanto no número de gols feitos ou sofridos. Talvez o setor que mais se beneficie seja o defensivo.
#
# Nosso conjunto de dados apresentou 6 casos onde tivemos 10 gols em uma única partida como podemos ver abaixo.

# %%
nhl_eda[nhl_eda['goals_for'] == 10]
# Out:
#               season type   date_time     team_name  goals_for  goals_against  \
# game_id
# 2011030144  20112012    P  2012-04-18      Penguins         10              3
# 2017020398  20172018    R  2017-12-03     Canadiens         10              1
# 2016020414  20162017    R  2016-12-11     Canadiens         10              1
# 2016020158  20162017    R  2016-11-04  Blue Jackets         10              0
# 2017020010  20172018    R  2017-10-06    Blackhawks         10              1
# 2010021148  20102011    R  2011-03-30         Blues         10              3
#
#              HoA settled_in        head_coach  shots  hits  pim  \
# game_id
# 2011030144  away        REG        Dan Bylsma     36    29   36
# 2017020398  home        REG     Claude Julien     34    16    4
# 2016020414  home        REG   Michel Therrien     36    11   10
# 2016020158  home        REG   John Tortorella     40    12    4
# 2017020010  home        REG  Joel Quenneville     44    27    4
# 2010021148  away        REG       Davis Payne     47    23    8
#
#             powerPlayOpportunities  powerPlayGoals  faceOffWinPercentage  \
# game_id
# 2011030144                       9               4                  58.0
# 2017020398                       2               1                  50.8
# 2016020414                       2               1                  70.2
# 2016020158                       5               4                  44.4
# 2017020010                       6               0                  54.9
# 2010021148                       4               2                  43.5
#
#             giveaways  takeaways outcome
# game_id
# 2011030144          7          4       W
# 2017020398         13          9       W
# 2016020414         10          7       W
# 2016020158          5          6       W
# 2017020010         11         10       W
# 2010021148          9          3       W

# %% [markdown]
# Na maioria dos resultados o time mandante foi o responsável pelo feito. A maior liderança foi do time do *Columbus Blue Jackets* contra *Montreal Canadiens* no dia 04/11/2016 da fase regular da temporada de 2016-2017. Você pode acessar o [link](https://www.nhl.com/bluejackets/video/recap-mtl-0-cbj-10/t-277437100/c-46026003) caso queira assistir aos gols

# %% [markdown]
# ### Evolucao dos gols feitos e sofridos dos times pelas temporadas

# %%
show_goals(df=nhl_eda)
# Out:
# Digite a fase que quer ver (r, p ou tudo): tudo
# Quer ver a soma total ou a media dos gols (total ou media): total

# %% [markdown]
# ### Hits
# O hóquei é um esporte onde o contato físico é intrínseco. O contato físico entre dois jogadores é denominado de "Hit" que é uma palavra para “choque corporal”.
#
# Quando um oponente está na posse do disco ou simplesmente desistiu da posse do disco, você pode usar o ombro ou o quadril para impedir seu progresso, aplicando um “choque corporal” que atinge a área do peito / ombro ou a área do quadril. Essa estatística fornece uma indicação de como fisicamente um indivíduo ou equipe joga contra seus oponentes.
#
#
# * Qual time acumula mais Hits e PIMs?
# * O jogo ficou mais fisico (mais hits) durante os anos (season) ouve aumento nas penalidades?
# * Os times com maior numero de hits e pim como foi o desempenho atraves das temporadas

# %% [markdown]
# #### Qual o time com mais hits na liga?

# %%
Image(filename="images/hits.png")

# %% [markdown]
# O time que apresentou o jogo mais físico na NHL foi ***Los Angeles Kings*** somando mais de 23 mil *hits* em 9 temporadas contabilizadas. Agora vamos ver a distribuição desses hits pelas temporadas.

# %%
Image(filename="images/kingshits.png")

# %% [markdown]
# Tivemos um resultado bastante interessante:
# * Nas duas oportunidades em que o time dos ***Los Angeles Kings*** foi campeão ele liderou a NHL em *hits* e desde da sua conquista em 2013-2014 o jogo físico do time de *Los Angeles* vem decaindo assim como a sua participação nos playoffs. Nos últimos 5 anos chegou a pós-temporada em apenas duas ocasiões em 2015-2016 onde venceu apenas um jogo e 2017-2018 onde acabou sendo varrido. Isso mostra que o jogo fisico do time era um diferencial e que a falta do mesmo vem sendo sentida.
#
# Como vimos o jogo físico dos ***Kings*** decaiu bastante nas ultimas temporadas, mas será que o mesmo se aplica a liga, o jogo tem ficando menos fisico?

# %%
Image(filename="images/nhlhits.png")

# %% [markdown]
# Diferente do que vimos no gráfico anterior que apresentou como o jogo do Los Angeles Kings tem ficado menos físico a cada nova temporada. Não podemos dizer o mesmo sobre a NHL onde o número de hits tem aumentado de forma gradual nas últimas duas temporadas. Esta longe do auge que foi a temporada de 2014-2015 com mais de 67 mil hits, mas o jogo mostra sinais de que pode chegar a superar tal marca.

# %%
season_hits_mean = nhl_eda.groupby(["season"])["hits"].mean()

for team in list(nhl_eda["team_name"].sort_values().unique()):
    teams_hits = nhl_eda[nhl_eda["team_name"]==team]

    fig, ax = plt.subplots(figsize=(9.5, 4))

    teams_hits.groupby(["season"])["hits"].mean().plot(label="media hits", color="black", linewidth=3, marker="o", ax=ax)
    season_hits_mean.plot(label="media NHL hits", color="silver", linewidth=2.5, marker="o", ax=ax)
    
    ax.set_title(team + ": media de hits por temporada", loc="left", weight="bold", fontsize=16, pad=25, alpha=0.55)

    # estilizando imagem
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set_ylim(10, 40)
    plt.tight_layout()

# %% [markdown]
# ### PIM
# Penalidade em Minutos (Penalty In Minutes - PIM) representa a duração total das penalidades atribuidas a um jogador ou equipe. Por exemplo, se um jogador em um jogo recebe uma minor (2 minutos) e uma major (5 minutos), o total desse jogo seria 7 PIMs. Com isso a equipe que sofreu a penalidade entra no Power Play e a equipe que cometeu a penalidade no Penalty Kill. Sao duas estatísticas bem interessantes porque medem a eficiência dos times tanto em vantagem como em desvantagem.

# %%
Image(filename="images/pimstimes.png")

# %% [markdown]
# O time do Flyers e o nosso grande lider com mais de 9 mil minutos de penalidades o equivalente a ~ 147 jogos so de faltas.

# %%
Image(filename="images/flyerspim.png")

# %% [markdown]
# Nosso grafico apresentou uma queda bem acentuada no numero de faltas por temporada, mas sera que a liga reagiu na mesma forma

# %%
Image(filename="images/pimstemp.png")

# %% [markdown]
# Desde da temporada de 2010-2011 que foi nosso auge em número de faltas é possível ver um grande declínio a cada nova temporada. Isso mostra o quanto o jogo está ficando mais “limpo” consequentemente mais dinâmico. De certa forma esse comportamento e de se esperar uma vez que ninguem quer se colocar em desvantagem

# %%
season_pim_mean = nhl_eda.groupby(["season"])["pim"].mean()

for team in list(nhl_eda["team_name"].sort_values().unique()):
    teams_pims = nhl_eda[nhl_eda["team_name"]==team]

    fig, ax = plt.subplots(figsize=(9.5, 4))

    teams_pims.groupby(["season"])["pim"].mean().plot(label="media " + team, color="black", linewidth=3, marker="o", ax=ax)
    season_pim_mean.plot(label="media NHL pim", color="silver", linewidth=2.5, marker="o", ax=ax)
    
    ax.set_title(team + ": PIMs por temporada", loc="left", fontsize=16, weight="bold", pad=35, alpha=0.45)

    # estilizando imagem
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
    ax.set_ylim(5, 20)
    plt.tight_layout()
